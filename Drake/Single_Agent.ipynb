# %% [markdown]
# <a href="https://colab.research.google.com/github/ravindyaparami/multi-agents-on-a-lie-group/blob/main/Drake/Single_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install drake
# Out:
# Collecting drake
#   Downloading drake-1.48.0-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from drake) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from drake) (2.0.2)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from drake) (4.0.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from drake) (6.0.3)
# Collecting Mosek==11.0.24 (from drake)
#   Downloading mosek-11.0.24-cp39-abi3-manylinux2014_x86_64.whl.metadata (698 bytes)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->drake) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->drake) (1.17.0)
# Downloading drake-1.48.0-cp312-cp312-manylinux_2_34_x86_64.whl (40.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 17.2 MB/s eta 0:00:00
# Downloading mosek-11.0.24-cp39-abi3-manylinux2014_x86_64.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 98.0 MB/s eta 0:00:00
# Installing collected packages: Mosek, drake
# Successfully installed Mosek-11.0.24 drake-1.48.0

# %%
import numpy as np

from pydrake.all import (
    DiagramBuilder,
    MultibodyPlant,
    SceneGraph,
    Simulator,
    SpatialInertia,
    UnitInertia,
    RigidTransform,
    Meshcat,
    MeshcatVisualizer,
    RollPitchYaw
)
